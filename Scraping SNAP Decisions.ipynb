# %% [markdown]
# # Scraping SNAP decision data from USDA.gov

# %% [markdown]
# I used Winny de Jong's super accessible <a href="https://datajournalism.com/watch/python-for-journalists">Python for Journalists</a> course on  datajournalism.com as my introduction to web scraping. From there, I taught myself to iterate across multiple pages.  Finally, I pair coded with a back-end engineer friend to learn other ways of achieving the same goals (storing data in a dictionary instead of a list; iterating through URLs; etc). Thanks, Winny and Nashaad!
#
# I decided to practice by scraping the USDA's list of SNAP retailers that have been blacklisted or OKed after complaints. When I started this project, my local corner store had recently started offering more groceries. But the owner told me could not accept SNAP because a former business partner had committed fraud. That's too bad, because great, my neighborhood had lots of EBT users, but not many grocery stores. SNAP blacklist decisions are final; I was curious how often similar situations impacted neighborhoods like mine.
#
# Steps:
# 1. Scrape and clean the SNAP decision data **(this notebook)**.
# 2. Compare the data against a map of food deserts and test my hypotheses:
#     - There are more blacklisted SNAP retailers in food deserts than in more-resourced areas
#     - If SNAP could be accepted at currently blacklisted locations, some food deserts would noticeably shrink.
# 4. Other directions to explore:
#     - Which partners have changed ownership since their decisions?
#     - Is there anything in the full text of the agency decisions worth looking into?

# %% [markdown]
# ## Approach #1
#
# Winny's approach is nice because it is simple; I summarized it below. The main drawback is that this way only scrapes one URL; I need to scrape 340.

# %%
# import libraries
# ----------------
import csv
import requests
from bs4 import BeautifulSoup
import pandas as pd

# prep csv file
# -------------
# create a csv file to store data from the page
f = open('SnapDecisions.csv', 'w', encoding='utf8', newline='') # (w = writeable)
# create a writer to write data to the csv
writer = csv.writer(f, delimiter=',') 
# write the header row
writer.writerow(['title', 'address', 'decision', 'decisionDate'])


# request and view page data
# --------------------------
# request the page; check that it loaded. Flashbacks to my website admin days! 
url = 'https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=1'
page = requests.get(url) #use the get function/method from the requests library to store the url in an object called page
# page
# grab the page HTML using Beautiful Soup; looks like a simple Drupal page w/ HTML table
soup = BeautifulSoup(page.content, 'html.parser')
# soup
# find the table; this page just has one
table = soup.find('table')
# table


"""
# explore data
# ------------
# find all the rows in the table; store in an object called "rows"
row = table.find_all('tr') # (table. or soup. both work since there is only one table)
rows
# if needed, find a specific row by row number (header row = 0)
rows[1]
# find all the cells in a given row (<th> = table header; <td> = table data)
cells = table.find_all('td')
cells = row[1].find_all('td')
# find a specific cell; use .text to view text without HTML
cells[0].text

"""

# organize data
# -------------
# create a for loop to store table data in a list. 
# 1. find each cell in a row; store in a variable called 'cells' 
# 2. the position of the cell determines it's column; create a header for each column
# 4. create a list of headers called rowData 
# 5. for each row in the table, create the rowData list and write to the csv
for row in table.find_all('tr'):
        cells = row.find_all(['th','td']) 
        title = cells[0].text
        address = cells[1].text
        decision = cells[2].text
        decisionDate = cells[3].text
        rowData = [title, address, decision, decisionDate]
#         print(rowData)
#         write to csv
#         ------------
        writer.writerow(rowData)

    
# check that it worked
# --------------------
# use the bash command "ls" to confirm that a file was created.
# ls
# confirm that the file contains data. Either check manually, or use a Pandas dataframe:
df = pd.read_csv('SnapDecisions.csv')
# df.shape # right amount of data?
df.head(5) # data looks right?
# Out:
#                           title  \
# 0                         Title
# 1  Bab El Salam Restaurant LLC
# 2               LK Mini Market
# 3                Euclid Market
# 4             Bali’s Food Mart
#
#                                              address          decision  \
# 0                                            Address               FAD
# 1  129 W. Centre Ave.  \nPortage, MI 49024-5335  ...  Denial
# 2  6025 Pacific Ave.  \nStockton, CA 95207            Denial
# 3  4268 Euclid Ave.  \nSan Diego, CA 92115-4977  ...  Denial
# 4  12259 Veterans Memorial Drive  \nHouston, TX 7...  Denial
#
#            decisionDate
# 0              FAD Date
# 1  10/26/2016
# 2  10/26/2016
# 3  10/12/2016
# 4  10/25/2016

# %% [markdown]
# # Approach #2
# Big thanks to my friend Nashaad, who helped me explore other ways to do this!
#
# New best practices I learned:
# - Use "f" in Python to format logically similar URLs, add them to a variable, and iterate through to avoid adding them manually like I did earlier.
# - Store row data in a dictionary instead of a list to give each cell an explicit key. This provides more context and gives the flexibility to view data with json instead of pandas, and to use json instead of a csv later.
# - Use "print" within a loop to track what the scraper is doing and throw errors.
# - Use short, random sleep steps instead of long, consistent ones to throttle without slowing your scraper down.
#
# Othr useful things I learned:
# - "print(TK.prettify())" - prints nicely formatted HTML.
# - You can use .find('a').get('b') together to find an constant and get a related variable.
# - "with open" opens AND closes your csv for you.
# - In Python, use "=" to define a variable or object; "def" to define a function.
# - Like in Excel, it is easy to replace or strip text in a string.

# %%
# import libraries
# ----------------
import csv
import requests
from bs4 import BeautifulSoup
from time import sleep
import random
import pandas as pd
import json


# define a function to parse table data, then write it to a csv
# -------------------------------------------------------------
def parse_and_csv(html):
    
    # request page data
    # -----------------
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table')
    
    """
    # make soup object for the first row of the csv--the header
    header = table.find('tr')
    headings = header.find_all('th')
    headings_list = []
    for th in headings:
        headings_list.append(th.text)
    """

    # make soup objects for the other rows in the csv--the data
    body = table.find('tbody')
    rows = body.find_all('tr')     

    
    # parse table data using a dictionary
    # -----------------------------------
    # store row data in a list
    rows_list = []
    for row in rows:
        tds = row.find_all('td')
        cells_dict = {
            # strip white space from text
            'Title': tds[0].text.strip(),
            # strip whitespace and line breaks from address field
            'Address': tds[1].text.replace('  \n', ', ').strip(),
            'Decision': tds[2].text.strip(),
            'Decision Date': tds[3].text.strip()
        }

        # make a list of dictionaries
        rows_list.append(cells_dict)
    
    
    # view dictionary using json
    # --------------------------
    # print(json.dumps(rows_list, indent=4))


    # write dictionary to the csv
    # ---------------------------
    with open('SNAPple.csv', mode='a') as event_file:
        #use the DictWriter argument to write dictionaries to a csv
        writer = csv.DictWriter(event_file, fieldnames=fieldnames, quoting=csv.QUOTE_ALL)
        # iterate through all the row_list items
        # and write row to csv
        for item in rows_list:
            writer.writerow(item)
            

    # check that it worked
    # --------------------        
    df = pd.read_csv('SNAPple.csv')
    df


# before running the function above, write the header row to the csv
# ------------------------------------------------------------------
with open('SNAPple.csv', mode='w') as event_file:
    # make a list of names for the header
    fieldnames = ['Title', 'Address', 'Decision', 'Decision Date']
    writer = csv.DictWriter(event_file, fieldnames=fieldnames, quoting=csv.QUOTE_ALL)
    # write the csv header (once)
    writer.writeheader() 
    
    
# now that the csv has a header, run the 'parse_and_csv' function for all pages
# -----------------------------------------------------------------------------
for i in range(340):
    # use f to format strings in python3
    url = f'https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page={i}'
    print(f'Currently scraping url: [{url}]')    # add a status message
    solong = random.randrange(0, 25)/100    # add a sleep step
    print(f'sleeping for {solong}')    # add a status message
    sleep(solong)
    
    # for i in range(): url = f'https...{i} pulls all urls into the url variable.
    # now, we can use "requests.get" in one fell swoop on all the urls.
    # this is where I was stuck earlier!
    page = requests.get(url)
    
    # if each page loads, run the "parse_and_csv" function defined above
    if page.status_code == 200:
        parse_and_csv(page.text)
    # if the page doesn't load, throw an error message
    else: 
        print(f'Cry for help from url {url}: Yikes, I am breaking!') 
        break
# Out:
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=0]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=1]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=2]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=3]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=4]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=5]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=6]
# sleeping for 0.23
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=7]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=8]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=9]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=10]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=11]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=12]
# sleeping for 0.01
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=13]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=14]
# sleeping for 0.15
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=15]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=16]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=17]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=18]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=19]
# sleeping for 0.11
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=20]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=21]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=22]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=23]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=24]
# sleeping for 0.21
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=25]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=26]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=27]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=28]
# sleeping for 0.21
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=29]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=30]
# sleeping for 0.23
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=31]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=32]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=33]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=34]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=35]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=36]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=37]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=38]
# sleeping for 0.1
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=39]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=40]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=41]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=42]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=43]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=44]
# sleeping for 0.01
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=45]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=46]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=47]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=48]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=49]
# sleeping for 0.11
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=50]
# sleeping for 0.14
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=51]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=52]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=53]
# sleeping for 0.1
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=54]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=55]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=56]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=57]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=58]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=59]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=60]
# sleeping for 0.17
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=61]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=62]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=63]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=64]
# sleeping for 0.1
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=65]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=66]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=67]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=68]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=69]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=70]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=71]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=72]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=73]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=74]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=75]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=76]
# sleeping for 0.14
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=77]
# sleeping for 0.11
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=78]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=79]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=80]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=81]
# sleeping for 0.01
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=82]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=83]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=84]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=85]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=86]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=87]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=88]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=89]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=90]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=91]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=92]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=93]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=94]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=95]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=96]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=97]
# sleeping for 0.15
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=98]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=99]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=100]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=101]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=102]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=103]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=104]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=105]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=106]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=107]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=108]
# sleeping for 0.23
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=109]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=110]
# sleeping for 0.17
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=111]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=112]
# sleeping for 0.1
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=113]
# sleeping for 0.23
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=114]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=115]
# sleeping for 0.1
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=116]
# sleeping for 0.11
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=117]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=118]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=119]
# sleeping for 0.1
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=120]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=121]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=122]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=123]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=124]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=125]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=126]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=127]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=128]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=129]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=130]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=131]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=132]
# sleeping for 0.14
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=133]
# sleeping for 0.21
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=134]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=135]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=136]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=137]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=138]
# sleeping for 0.17
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=139]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=140]
# sleeping for 0.11
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=141]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=142]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=143]
# sleeping for 0.14
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=144]
# sleeping for 0.21
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=145]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=146]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=147]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=148]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=149]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=150]
# sleeping for 0.17
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=151]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=152]
# sleeping for 0.11
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=153]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=154]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=155]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=156]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=157]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=158]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=159]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=160]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=161]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=162]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=163]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=164]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=165]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=166]
# sleeping for 0.1
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=167]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=168]
# sleeping for 0.23
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=169]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=170]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=171]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=172]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=173]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=174]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=175]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=176]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=177]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=178]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=179]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=180]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=181]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=182]
# sleeping for 0.23
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=183]
# sleeping for 0.01
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=184]
# sleeping for 0.14
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=185]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=186]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=187]
# sleeping for 0.11
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=188]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=189]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=190]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=191]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=192]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=193]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=194]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=195]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=196]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=197]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=198]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=199]
# sleeping for 0.01
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=200]
# sleeping for 0.15
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=201]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=202]
# sleeping for 0.01
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=203]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=204]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=205]
# sleeping for 0.17
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=206]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=207]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=208]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=209]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=210]
# sleeping for 0.1
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=211]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=212]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=213]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=214]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=215]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=216]
# sleeping for 0.14
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=217]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=218]
# sleeping for 0.15
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=219]
# sleeping for 0.23
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=220]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=221]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=222]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=223]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=224]
# sleeping for 0.15
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=225]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=226]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=227]
# sleeping for 0.01
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=228]
# sleeping for 0.21
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=229]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=230]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=231]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=232]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=233]
# sleeping for 0.17
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=234]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=235]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=236]
# sleeping for 0.23
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=237]
# sleeping for 0.15
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=238]
# sleeping for 0.11
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=239]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=240]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=241]
# sleeping for 0.23
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=242]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=243]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=244]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=245]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=246]
# sleeping for 0.01
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=247]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=248]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=249]
# sleeping for 0.15
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=250]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=251]
# sleeping for 0.21
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=252]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=253]
# sleeping for 0.1
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=254]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=255]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=256]
# sleeping for 0.14
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=257]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=258]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=259]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=260]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=261]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=262]
# sleeping for 0.24
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=263]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=264]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=265]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=266]
# sleeping for 0.21
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=267]
# sleeping for 0.0
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=268]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=269]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=270]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=271]
# sleeping for 0.21
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=272]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=273]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=274]
# sleeping for 0.21
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=275]
# sleeping for 0.21
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=276]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=277]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=278]
# sleeping for 0.17
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=279]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=280]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=281]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=282]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=283]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=284]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=285]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=286]
# sleeping for 0.11
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=287]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=288]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=289]
# sleeping for 0.14
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=290]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=291]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=292]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=293]
# sleeping for 0.08
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=294]
# sleeping for 0.09
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=295]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=296]
# sleeping for 0.22
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=297]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=298]
# sleeping for 0.15
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=299]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=300]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=301]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=302]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=303]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=304]
# sleeping for 0.18
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=305]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=306]
# sleeping for 0.07
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=307]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=308]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=309]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=310]
# sleeping for 0.2
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=311]
# sleeping for 0.04
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=312]
# sleeping for 0.15
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=313]
# sleeping for 0.14
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=314]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=315]
# sleeping for 0.19
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=316]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=317]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=318]
# sleeping for 0.23
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=319]
# sleeping for 0.13
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=320]
# sleeping for 0.05
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=321]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=322]
# sleeping for 0.01
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=323]
# sleeping for 0.23
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=324]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=325]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=326]
# sleeping for 0.11
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=327]
# sleeping for 0.11
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=328]
# sleeping for 0.02
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=329]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=330]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=331]
# sleeping for 0.12
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=332]
# sleeping for 0.16
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=333]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=334]
# sleeping for 0.15
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=335]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=336]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=337]
# sleeping for 0.03
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=338]
# sleeping for 0.06
# Currently scraping url: [https://www.fns.usda.gov/snap/fad?title=&field_fiscal_year_value=&page=339]
# sleeping for 0.05
